# %%
import pandas as pd
import numpy as np

# %%
original_data = pd.read_csv('creditcard.csv').rename(columns={'Class': 'isFraud'})
original_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
original_data['isFraud'].value_counts()
# Out:
# isFraud
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## Split Fraud Data

# %%
fraud_data = original_data[original_data['isFraud'] == 1]
fraud_data.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545  \
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...       V21       V22       V23
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211  \
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  isFraud
# ...

# %%
fraud_data = fraud_data.sample(n=490)
fraud_data.to_csv('credit_fraud_data.csv', index=False)

# %% [markdown]
# ## Split Normal Data

# %%
normal_data = original_data[original_data['isFraud'] == 0]
normal_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599  \
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539  \
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
for i in range(1,4):
    normal_batch = normal_data.sample(n=8000)
    normal_batch.to_csv('credit_normal_{}.csv'.format(i), index=False)

# %% [markdown]
# ## Concat Small Batches

# %%
fraud_data = pd.read_csv('credit_fraud_data.csv')
fraud_data
# Out:
#          Time         V1        V2         V3         V4         V5        V6
# 0     88672.0  -3.859881  2.632881  -5.264265   3.446113  -0.675231 -1.904959  \
# 1     62059.0  -1.644403  3.129852  -2.576977   3.415573  -0.448525 -1.241893
# 2     13323.0  -5.454362  8.287421 -12.752811   8.594342  -3.106002 -3.179949
# 3     93965.0 -11.397727  7.763953 -18.572307   6.711855 -10.174216 -4.395918
# 4     52934.0   1.036639  0.407227   0.757706   3.161821  -0.568122  0.202181
# ..        ...        ...       ...        ...        ...        ...       ...
# 485   17520.0  -5.268053  9.067613 -15.960728  10.296603  -4.708241 -3.395375
# 486  160895.0  -0.848290  2.719882  -6.199070   3.044437  -3.301910 -1.992117
# 487   77171.0   1.118560  1.291858  -1.298805   2.135772   0.772204 -1.147291
# 488   40086.0   1.083693  1.179501  -1.346150   1.998824   0.818034 -0.771419
# 489  142394.0  -3.367770  0.099249  -6.148487   3.401955   0.458307 -1.571630
#
# ...

# %%
for i in range(1,4):
    normal_batch = pd.read_csv('credit_normal_{}.csv'.format(i))
    batch = pd.concat([fraud_data, normal_batch])
    
    batch.to_csv('credit_batch_{}.csv'.format(i), index=False)

# %% [markdown]
# ## Check Balance in Batch

# %%
batch_1 = pd.read_csv('credit_batch_1.csv')
batch_1
# Out:
#           Time         V1        V2         V3        V4         V5        V6
# 0      88672.0  -3.859881  2.632881  -5.264265  3.446113  -0.675231 -1.904959  \
# 1      62059.0  -1.644403  3.129852  -2.576977  3.415573  -0.448525 -1.241893
# 2      13323.0  -5.454362  8.287421 -12.752811  8.594342  -3.106002 -3.179949
# 3      93965.0 -11.397727  7.763953 -18.572307  6.711855 -10.174216 -4.395918
# 4      52934.0   1.036639  0.407227   0.757706  3.161821  -0.568122  0.202181
# ...        ...        ...       ...        ...       ...        ...       ...
# 8485  160397.0  -0.192524  1.363424  -0.724383 -0.500326   0.665068 -0.901764
# 8486  120263.0   2.043835 -0.070013  -1.166280  0.219817   0.115927 -0.694396
# 8487   46083.0  -0.795755  0.440031   2.043941 -1.388290  -0.357002 -0.086266
# 8488  146582.0   1.832608 -1.030195  -1.111408 -0.471876   1.224440  4.263618
# 8489   76505.0   0.972874 -0.236595   0.902213  1.479642  -0.520477  0.627772
#
# ...

# %%
batch_1['isFraud'].value_counts()
# Out:
# isFraud
# 0    8000
# 1     490
# Name: count, dtype: int64
